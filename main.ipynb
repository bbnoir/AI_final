# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1MGS2BZMzd_FtW4xPv4IHg9sXL_W38UR3' -O Set5.zip
# !unzip -o Set5.zip
# Out:
# --2023-08-03 14:55:14--  https://docs.google.com/uc?export=download&id=1MGS2BZMzd_FtW4xPv4IHg9sXL_W38UR3
# Resolving docs.google.com (docs.google.com)... 173.194.193.138, 173.194.193.101, 173.194.193.102, ...
# Connecting to docs.google.com (docs.google.com)|173.194.193.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-00-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/uvuhli94elqmtqq17kr5ap39ofkvnpq8/1691074500000/08385357638811564126/*/1MGS2BZMzd_FtW4xPv4IHg9sXL_W38UR3?e=download&uuid=645d98f7-3e0e-4734-be62-d7e51fb46af5 [following]
# Warning: wildcards not supported in HTTP.
# --2023-08-03 14:55:15--  https://doc-00-68-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/uvuhli94elqmtqq17kr5ap39ofkvnpq8/1691074500000/08385357638811564126/*/1MGS2BZMzd_FtW4xPv4IHg9sXL_W38UR3?e=download&uuid=645d98f7-3e0e-4734-be62-d7e51fb46af5
# Resolving doc-00-68-docs.googleusercontent.com (doc-00-68-docs.googleusercontent.com)... 173.194.198.132, 2607:f8b0:4001:c1c::84
# Connecting to doc-00-68-docs.googleusercontent.com (doc-00-68-docs.googleusercontent.com)|173.194.198.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 972966 (950K) [application/x-zip-compressed]
# Saving to: ‘Set5.zip’
#
# Set5.zip            100%[===================>] 950.16K  --.-KB/s    in 0.007s
#
# 2023-08-03 14:55:15 (129 MB/s) - ‘Set5.zip’ saved [972966/972966]
#
# Archive:  Set5.zip
#    creating: Set5/LRbicx3/
#   inflating: Set5/LRbicx3/baby.png
#   inflating: Set5/LRbicx3/bird.png
#   inflating: Set5/LRbicx3/butterfly.png
#  extracting: Set5/LRbicx3/head.png
#   inflating: Set5/LRbicx3/woman.png
#    creating: Set5/original/
#   inflating: Set5/original/baby.png
#   inflating: Set5/original/bird.png
#   inflating: Set5/original/butterfly.png
#   inflating: Set5/original/head.png
#   inflating: Set5/original/woman.png

# %%
# !pip install -r requirements.txt
# !pip install thop
# Out:
# Collecting einops (from -r requirements.txt (line 1))
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 887.4 kB/s eta 0:00:00
# Collecting thop (from -r requirements.txt (line 2))
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Collecting basicsr (from -r requirements.txt (line 3))
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from thop->-r requirements.txt (line 2)) (2.0.1+cu118)
# Collecting addict (from basicsr->-r requirements.txt (line 3))
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (0.18.3)
# Collecting lmdb (from basicsr->-r requirements.txt (line 3))
#   Downloading lmdb-1.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (1.22.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (4.7.0.72)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (2.27.1)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (0.19.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (1.10.1)
# Collecting tb-nightly (from basicsr->-r requirements.txt (line 3))
#   Downloading tb_nightly-2.14.0a20230803-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 62.2 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (0.15.2+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from basicsr->-r requirements.txt (line 3)) (4.65.0)
# Collecting yapf (from basicsr->-r requirements.txt (line 3))
#   Downloading yapf-0.40.1-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.3/250.3 kB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->thop->-r requirements.txt (line 2)) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->thop->-r requirements.txt (line 2)) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->thop->-r requirements.txt (line 2)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->thop->-r requirements.txt (line 2)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->thop->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->thop->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->thop->-r requirements.txt (line 2)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->thop->-r requirements.txt (line 2)) (16.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr->-r requirements.txt (line 3)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr->-r requirements.txt (line 3)) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr->-r requirements.txt (line 3)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->basicsr->-r requirements.txt (line 3)) (3.4)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr->-r requirements.txt (line 3)) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr->-r requirements.txt (line 3)) (2023.7.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr->-r requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->basicsr->-r requirements.txt (line 3)) (23.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (1.56.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tb-nightly->basicsr->-r requirements.txt (line 3)) (0.41.0)
# Collecting importlib-metadata>=6.6.0 (from yapf->basicsr->-r requirements.txt (line 3))
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.10/dist-packages (from yapf->basicsr->-r requirements.txt (line 3)) (3.9.1)
# Requirement already satisfied: tomli>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from yapf->basicsr->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr->-r requirements.txt (line 3)) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr->-r requirements.txt (line 3)) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tb-nightly->basicsr->-r requirements.txt (line 3)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tb-nightly->basicsr->-r requirements.txt (line 3)) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=6.6.0->yapf->basicsr->-r requirements.txt (line 3)) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tb-nightly->basicsr->-r requirements.txt (line 3)) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->thop->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tb-nightly->basicsr->-r requirements.txt (line 3)) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tb-nightly->basicsr->-r requirements.txt (line 3)) (3.2.2)
# Building wheels for collected packages: basicsr
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214824 sha256=2c3e81476499ab0b0a2e0357f42adc1ba4f9210d0e253d78da35b8b8f2f53566
#   Stored in directory: /root/.cache/pip/wheels/38/83/99/2d8437cc652a01af27df5ff037a4075e95b52d67705c5f30ca
# Successfully built basicsr
# Installing collected packages: lmdb, addict, importlib-metadata, einops, yapf, tb-nightly, thop, basicsr
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 4.6.4
#     Uninstalling importlib-metadata-4.6.4:
#       Successfully uninstalled importlib-metadata-4.6.4
# Successfully installed addict-2.4.0 basicsr-1.4.2 einops-0.6.1 importlib-metadata-6.8.0 lmdb-1.4.1 tb-nightly-2.14.0a20230803 thop-0.1.1.post2209072238 yapf-0.40.1
# Requirement already satisfied: thop in /usr/local/lib/python3.10/dist-packages (0.1.1.post2209072238)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from thop) (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->thop) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->thop) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->thop) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->thop) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->thop) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->thop) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->thop) (1.3.0)

# %%
# !python3 demo.py
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Number of LR imgs (patches): 5     , Number of HR imgs (patches): 5
# ================================EVALUATION=============================
# Tesing: baby.png            , PSNR: 34.07659149169922
# Tesing: bird.png            , PSNR: 35.03059387207031
# Tesing: butterfly.png       , PSNR: 29.216663360595703
# Tesing: head.png            , PSNR: 30.80173683166504
# Tesing: woman.png           , PSNR: 31.44120979309082
#
# Average PSNR: 32.113 dB
#
# ============================
# FLOPs : 10.232660832 G
# PARAMS : 0.071745 M
# ============================
# Your FLOPs is smaller than 11.1 G.
# You will get this 10 points.
# Congratulations !!!
# ============================
# Overall Ranking Score: 248305.078
# ============================
# Your score on Kaggle should be 224.455978
# ============================
